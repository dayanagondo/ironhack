# %% [markdown]
# ![Ironhack logo](https://i.imgur.com/1QgrNNw.png)
#
#
#
#
#
# # Project 1 - Game | **IronQuiz**
#
# ## Introduction
#
# *   **Tempo do projeto**: 1 semana
# *   **Participantes**: Dayana e Wagner
#
# ## Basics Concepts Used:
#
# *  **Função**
# *  **Lista**
# *  **For Loop and While**
# *  **String Operations**
#
# ## About the game:
#
# Esse é um jogo de perguntas e respostas de conceitos gerais.
#
#
# *  **Para ganhar**: É necessário que acerte pelo menos metade do banco de respostas (:
#
# *  **Lembre-se**: É necessário responder dentro das alternativas solicitadas. Uma vez que isso não ocorrer, nosso jogo retornará a pergunta para você responder novamente!
#
#
#
# **DIVIRTA-SE! FOI FEITO COM CARINHO =D**

# %%
possibles = ["a","b","c","d","e"]


def input_resp():
  """ Essa função pede para o usuário dar a resposta dele, podendo ser 'a' 'b' 'c' 'd' ou 'e' """
  
  answer = ''
  
  while answer not in possibles:
    answer = input("\033[1m Qual a alternativa correta (a,b,c,d ou e)? \033[0m \n")
  return answer

def player_name():
  name = input("Qual o seu nome: \n")
  return name

def correct_answer():
  print('\033[92m Correct answer!! Congrats \033[0m')
  return 1

def wrong_answer():
  print('\033[91m Not this time ): Try another one!\033[0m')
  return 0

def pergunta1():
  global score
  print("\n\033[1m Em que ordem surgiram os modelos atômicos? \033[0m \n\n a - Thomson Dalton Rutherford Rutherford-Bohr \n b - Rutherford-Bohr Rutherford Thomson Dalton \n c - Dalton Rutherford-Bohr Thomson Rutherford \n d - Dalton Thomson Rutherford-Bohr Rutherford \n e - Dalton Thomson Rutherford Rutherford-Bohr\n")
  
  players_answer1 = input_resp()
  
  if players_answer1 == 'e':
    score += correct_answer()

  else:
    wrong_answer()
def pergunta2():
  global score
  print('\n\033[1m Qual o maior animal terrestre?\033[0m \n\n a - Baleia Azul \n b - Dinossauro \n c - Elefante africano \n d - Tubarão Branco \n e - Girafa \n')
  
  players_answer1 = input_resp()

  if players_answer1 == 'c':
    score += correct_answer()

  else:
    wrong_answer()

def pergunta3():
  global score
  print('\n\033[1m Qual o nome completo do Andre? \033[0m \n\n a - André de Oliveira Aguilar \n b - André Ribeiro de Barros Aguiar \n c - Alexandre Aguiar \n d - André Ribeiro de Barros Aguilar \n e - André Chicleteiro\n')
  
  players_answer1 = input_resp()
  
  if players_answer1 == 'b' or players_answer1 == 'e':
    score += correct_answer()
  else:
    wrong_answer()

def pergunta4():
    global score
    print('\n\033[1m Qual o personagem mais querido do mundo dos games? \033[0m\n\na - Mario \nb - Sonic\nc - Pacman\nd - Kong (DonkeyKong) \ne - Link \n')
    
    players_answer2 = input_resp()
    
    if players_answer2 == 'a':
        score += correct_answer()
    else:
        wrong_answer()

def pergunta5():
    global score
    print('\n\033[1m Qual Frase Getúlio Vargas Pronunciou antes de se suicidar?\033[0m\n\n a - sair da vida pra morte \n b - entrei na eternidade pra sair da vida \n c - Sair da vida pra entrar na História \n d - sair de casa pra morte \n')
    
    players_answer2 = input_resp()
    
    if players_answer2 == 'c':
        score += correct_answer()
    else:
        wrong_answer()

def pergunta6():
    global score
    print('\n\033[1m Qual a temperatura necessária para a gasolina congelar? \033[0m \n\n a - 100 graus centigrados \n b - 117,5 graus centigrados \n c - 350,4 graus centigrados \n d - Nunca congela \n e - 165,0 graus centigrados')
    
    players_answer2 = input_resp()
    
    if players_answer2 == 'd':
        score += correct_answer()
        
    else:
        wrong_answer()

import random 
from time import sleep

x = pergunta1
y = pergunta2
z = pergunta3
u = pergunta4
v = pergunta5
w = pergunta6


score = 0
list_quest = [u,v,w,x,y,z]
nome = player_name()

def list_of_quest():
  secs = 0
  print("Let's start the game, be prepare! =D")

  for random_quest in range(len(list_quest)):

    if score == 3:
      print("Congrats,",nome,f'! Your pontuation is: {score}')
      break
      
  
    else:
      random_quest = random.choice(list_quest)
      random_quest()
      list_quest.remove(random_quest)
      print(score)

list_of_quest()
# Out:
# Qual o seu nome:
# Wagner
# Let's start the game, be prepare! =D
#
#  Qual o nome completo do Andre?
#
#  a - André de Oliveira Aguilar
#  b - André Ribeiro de Barros Aguiar
#  c - Alexandre Aguiar
#  d - André Ribeiro de Barros Aguilar
#  e - André Chicleteiro
#
#  Qual a alternativa correta (a,b,c,d ou e)?
# a
#  Not this time ): Try another one!
# 0
#
#  Qual o maior animal terrestre?
#
#  a - Baleia Azul
#  b - Dinossauro
#  c - Elefante africano
#  d - Tubarão Branco
#  e - Girafa
#
#  Qual a alternativa correta (a,b,c,d ou e)?
# e
#  Not this time ): Try another one!
# 0
#
#  Qual o personagem mais querido do mundo dos games?
#
# a - Mario
# b - Sonic
# c - Pacman
# d - Kong (DonkeyKong)
# e - Link
#
#  Qual a alternativa correta (a,b,c,d ou e)?
# f
#  Qual a alternativa correta (a,b,c,d ou e)?
# c
#  Not this time ): Try another one!
# 0
#
#  Qual a temperatura necessária para a gasolina congelar?
#
#  a - 100 graus centigrados
#  b - 117,5 graus centigrados
# ...
